# %% [markdown]
# # Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
import pprint
from crewai import Agent, Task, Crew

# %% [markdown]
# ## Set OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

pprint.pprint(f"Agents Config: {agents_config}")

# print(f"Tasks Config: {tasks_config}")
# Out:
# ("Agents Config: {'project_planning_agent': {'role': 'The Ultimate Project "
#  "Planner\\n', 'goal': 'To meticulously break down the {project_type} project "
#  'into actionable tasks, ensuring no detail is overlooked, and setting precise '
#  'timelines that align with the {project_objectives}.\\n\', \'backstory\': "As '
#  'a veteran project manager, you’ve led numerous successful projects, '
#  'particularly in {industry}. Your keen eye for detail and strategic thinking '
#  'have always ensured that projects are delivered on time and within scope. '
#  "Now, you're tasked with planning the next groundbreaking {project_type} "
#  'project.\\n", \'allow_delegation\': False, \'verbose\': True}, '
#  "'estimation_agent': {'role': 'Expert Estimation Analyst\\n', 'goal': "
#  "'Provide highly accurate time, resource, and effort estimations for each "
#  'task in the {project_type} project to ensure it is delivered efficiently and '
#  "on budget.\\n', 'backstory': 'You are the go-to expert for project "
#  'estimation in {industry}. With a wealth of experience and access to vast '
#  'historical data, you can predict the resources required for any task with '
#  'remarkable accuracy. Your precision ensures that the {project_type} project '
#  "remains feasible and avoids unnecessary delays or budget overruns.\\n', "
#  "'allow_delegation': False, 'verbose': True}, 'resource_allocation_agent': "
#  '{\'role\': \'Resource Allocation Strategist\\n\', \'goal\': "Optimize the '
#  'allocation of tasks for the {project_type} project by balancing team '
#  "members' skills, availability, and current workload to maximize efficiency "
#  'and project success.\\n", \'backstory\': \'With a deep understanding of team '
#  'dynamics and resource management in {industry}, you have a track record of '
#  'ensuring that the right person is always assigned to the right task. Your '
#  'strategic thinking ensures that the {project_type} project team is utilized '
#  "to its full potential without overburdening any individual.\\n', "
#  "'allow_delegation': False, 'verbose': True}}")

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- PM Pro (Project Manager)
- Architect Aaron (Architect)
- Software Eng Doe (Software Engineer)
- Designer Smith (Designer)
- QA Johnson (QA Engineer)
- QA Brown (QA Engineer)
- Creator Moe (Content Creator)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - PM Pro (Project Manager)
# - Architect Aaron (Architect)
# - Software Eng Doe (Software Engineer)
# - Designer Smith (Designer)
# - QA Johnson (QA Engineer)
# - QA Brown (QA Engineer)
# - Creator Moe (Content Creator)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - PM Pro (Project Manager)
# - Architect Aaron (Architect)
# - Software Eng Doe (Software Engineer)
# - Designer Smith (Designer)
# - QA Johnson (QA Engineer)
# - QA Brown (QA Engineer)
# - Creator Moe (Content Creator)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# ### Website Project Breakdown
#
# **Project Overview:**
# This project aims to create a responsive, modern website for a small business. The deliverables will include essential pages and features that support the business's online presence and customer engagement.
#
# ### Comprehensive List of Tasks
#
# 1. **Requirement Gathering**
#    - **Description:** Initiate discussions with stakeholders to gather website requirements.
#    - **Timeline:** Weeks 1-2
#    - **Dependencies:** N/A
#    - **Deliverables:** Requirements specification document.
#
# 2. **Create Wireframes & Design**
#    - **Description:** Develop wireframes for all key pages (Home, About Us, Services, Contact Us, Blog, Testimonials) and finalize visual design concepts.
#    - **Timeline:** Weeks 2-4
#    - **Dependencies:** Completion of requirement gathering.
#    - **Deliverables:** Wireframe mockups and design prototypes.
#    - **Team Member Responsible:** Designer Smith.
#
# 3. **Responsive Design Implementation**
#    - **Description:** Implement responsive web design to ensure compatibility with both desktop and mobile devices.
#    - **Timeline:** Weeks 5-6
#    - **Dependencies:** Completion of wireframes and design.
#    - **Deliverables:** Responsive web pages.
#    - **Team Member Responsible:** Architect Aaron.
#
# 4. **User Interface Development**
#    - **Description:** Create a modern and visually appealing UI using the latest design trends.
#    - **Timeline:** Weeks 6-8
#    - **Dependencies:** Completion of responsive design.
#    - **Deliverables:** Implemented UI in the development environment.
#    - **Team Member Responsible:** Software Eng Doe.
#
# 5. **Navigation Structure Development**
#    - **Description:** Design and implement a user-friendly navigation system with an intuitive menu layout.
#    - **Timeline:** Weeks 7-9
#    - **Dependencies:** Completion of UI development.
#    - **Deliverables:** Functioning navigation bar and footers across the site.
#    - **Team Member Responsible:** Software Eng Doe.
#
# 6. **Content Creation for "About Us" Page**
#    - **Description:** Write and obtain approval for the content that highlights the company's history and values.
#    - **Timeline:** Weeks 3-4
#    - **Dependencies:** N/A
#    - **Deliverables:** Finalized content document for the "About Us" page.
#    - **Team Member Responsible:** Creator Moe.
#
# 7. **"Services" Page Design and Development**
#    - **Description:** Develop a "Services" page showcasing the business offerings, including descriptions and visuals.
#    - **Timeline:** Weeks 9-10
#    - **Dependencies:** Completion of content for each service description.
#    - **Deliverables:** Services page live on the website.
#    - **Team Member Responsible:** Software Eng Doe & Creator Moe.
#
# 8. **"Contact Us" Page Design**
#    - **Description:** Create a contact form with an embedded map using Google Maps API.
#    - **Timeline:** Weeks 10-11
#    - **Dependencies:** Completion of Services page.
#    - **Deliverables:** Live "Contact Us" page.
#    - **Team Member Responsible:** Software Eng Doe.
#
# 9. **Blog Section Implementation**
#    - **Description:** Set up a blog section for posting industry news and company updates.
#    - **Timeline:** Weeks 11-12
#    - **Dependencies:** Completion of "Contact Us" page.
#    - **Deliverables:** Functional blog on the site.
#    - **Team Member Responsible:** Software Eng Doe.
#
# 10. **SEO and Performance Optimization**
#     - **Description:** Ensure site loading speed is optimized and apply best practices for SEO.
#     - **Timeline:** Weeks 12-13
#     - **Dependencies:** Completion of all the main website pages.
#     - **Deliverables:** SEO report, optimized site.
#     - **Team Member Responsible:** QA Johnson & QA Brown.
#
# 11. **Social Media Integration**
#     - **Description:** Integrate social media links and sharing capabilities on the website.
#     - **Timeline:** Weeks 13-14
#     - **Dependencies:** Completion of SEO optimization.
#     - **Deliverables:** Social media buttons working.
#     - **Team Member Responsible:** Software Eng Doe.
#
# 12. **Testimonials Section Design**
#     - **Description:** Create a testimonials section to showcase customer feedback and build trust.
#     - **Timeline:** Weeks 14-15
#     - **Dependencies:** Completion of the main pages and SEO.
#     - **Deliverables:** Live testimonials section.
#     - **Team Member Responsible:** Creator Moe.
#
# 13. **Quality Assurance Testing**
#     - **Description:** Test the functionality and responsiveness of the website on various devices.
#     - **Timeline:** Weeks 15-16
#     - **Dependencies:** Completion of all prior tasks.
#     - **Deliverables:** QA testing report with any bugs identified.
#     - **Team Members Responsible:** QA Johnson & QA Brown.
#
# 14. **Final Review and Client Approval**
#     - **Description:** Conduct a final review with the client for feedback and approval to launch the website.
#     - **Timeline:** Weeks 16-17
#     - **Dependencies:** Successful QA completion.
#     - **Deliverables:** Client approval confirmation.
#     - **Team Member Responsible:** PM Pro.
#
# 15. **Deployment and Launch**
#     - **Description:** Deploy the website to the live server and conduct final checks.
#     - **Timeline:** Week 17
#     - **Dependencies:** Client approval confirmation.
#     - **Deliverables:** Live website.
#     - **Team Member Responsible:** Software Eng Doe & PM Pro.
#
# ### Gantt Chart Visualization
# ```
# | Task                                | Week 1 | Week 2 | Week 3 | Week 4 | Week 5 | Week 6 | Week 7 | Week 8 | Week 9 | Week 10 | Week 11 | Week 12 | Week 13 | Week 14 | Week 15 | Week 16 | Week 17 |
# |-------------------------------------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|---------|---------|---------|---------|---------|---------|---------|
# | Requirement Gathering                |   ■■■  |        |        |        |        |        |        |        |        |         |         |         |         |         |         |         |         |
# | Create Wireframes & Design          |        |   ■■■  |   ■■■  |        |        |        |        |        |        |         |         |         |         |         |         |         |         |
# | Responsive Design Implementation     |        |        |        |        |   ■■■  |   ■■■  |        |        |        |         |         |         |         |         |         |         |         |
# | User Interface Development           |        |        |        |        |        |   ■■■  |   ■■■  |        |        |         |         |         |         |         |         |         |         |
# | Navigation Structure Development     |        |        |        |        |        |        |   ■■■  |   ■■■  |        |         |         |         |         |         |         |         |         |
# | Content Creation for "About Us" Page|        |        |   ■■■  |   ■■■  |        |        |        |        |        |         |         |         |         |         |         |         |         |
# | "Services" Page Design and Development|       |        |        |        |        |        |        |        |   ■■■   |   ■■■   |         |         |         |         |         |         |         |
# | "Contact Us" Page Design            |        |        |        |        |        |        |        |        |        |         |   ■■■   |   ■■■   |         |         |         |         |         |
# | Blog Section Implementation          |        |        |        |        |        |        |        |        |        |         |         |   ■■■   |   ■■■   |         |         |         |         |
# | SEO and Performance Optimization     |        |        |        |        |        |        |        |        |        |         |         |         |   ■■■   |   ■■■   |         |         |         |
# | Social Media Integration             |        |        |        |        |        |        |        |        |        |         |         |         |         |   ■■■   |   ■■■   |         |         |
# | Testimonials Section Design          |        |        |        |        |        |        |        |        |        |         |         |         |         |         |   ■■■   |   ■■■   |         |
# | Quality Assurance Testing            |        |        |        |        |        |        |        |        |        |         |         |         |         |         |         |   ■■■   |   ■■■   |
# | Final Review and Client Approval     |        |        |        |        |        |        |        |        |        |         |         |         |         |         |         |         |   ■■■   |
# | Deployment and Launch               |        |        |        |        |        |        |        |        |        |         |         |         |         |         |         |         |   ■■■   |
# ```
#
# ### Conclusion
#
# This detailed task breakdown, along with clear timelines and deliverables, provides a well-structured outline for the successful completion of the website project. Each task's dependencies ensure that we move through the process methodically, while the Gantt chart offers a visual representation to aid in tracking progress.
#
# By addressing each element with thorough precision and clear accountability among team members, we set the stage for a successful project completion, launching the website on time and with all features functioning optimally.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Estimation Report for Website Project
#
# This detailed estimation report outlines the time, resources, and effort required for each task in the Website project, along with a summary of risks and uncertainties associated with the estimations.
#
# #### Task Breakdown and Estimations
#
# 1. **Requirement Gathering**
#    - **Estimated Time:** 2 weeks
#    - **Resources Required:** 1 Project Manager, 1 Business Analyst
#    - **Effort:** 80 hours
#    - **Deliverables:** Requirements specification document.
#    - **Risks/Uncertainties:** Stakeholder availability may delay finalization.
#
# 2. **Create Wireframes & Design**
#    - **Estimated Time:** 2 weeks
#    - **Resources Required:** 1 Designer
#    - **Effort:** 60 hours (30 hours per week)
#    - **Deliverables:** Wireframe mockups and design prototypes.
#    - **Risks/Uncertainties:** Feedback iterations may extend the timeline leading to a potential overlap with subsequent tasks.
#
# 3. **Responsive Design Implementation**
#    - **Estimated Time:** 2 weeks
#    - **Resources Required:** 1 Web Architect
#    - **Effort:** 80 hours
#    - **Deliverables:** Responsive web pages.
#    - **Risks/Uncertainties:** Technical challenges in cross-device compatibility could arise.
#
# 4. **User Interface Development**
#    - **Estimated Time:** 2 weeks
#    - **Resources Required:** 1 Software Engineer
#    - **Effort:** 80 hours
#    - **Deliverables:** Implemented UI in the development environment.
#    - **Risks/Uncertainties:** Design complexity could cause delays.
#
# 5. **Navigation Structure Development**
#    - **Estimated Time:** 2 weeks
#    - **Resources Required:** 1 Software Engineer
#    - **Effort:** 40 hours
#    - **Deliverables:** Functioning navigation bar and footers across the site.
#    - **Risks/Uncertainties:** Integration issues with the UI could extend this task.
#
# 6. **Content Creation for "About Us" Page**
#    - **Estimated Time:** 2 weeks
#    - **Resources Required:** 1 Content Creator
#    - **Effort:** 30 hours
#    - **Deliverables:** Finalized content document for the "About Us" page.
#    - **Risks/Uncertainties:** Content approval from stakeholders may take longer than expected.
#
# 7. **"Services" Page Design and Development**
#    - **Estimated Time:** 2 weeks
#    - **Resources Required:** 1 Software Engineer, 1 Content Creator
#    - **Effort:** 60 hours (30 hours per role)
#    - **Deliverables:** Services page live on the website.
#    - **Risks/Uncertainties:** Dependencies on "About Us" content approval could lead to delays.
#
# 8. **"Contact Us" Page Design**
#    - **Estimated Time:** 2 weeks
#    - **Resources Required:** 1 Software Engineer
#    - **Effort:** 40 hours
#    - **Deliverables:** Live "Contact Us" page.
#    - **Risks/Uncertainties:** Potential API integration challenges with Google Maps.
#
# 9. **Blog Section Implementation**
#    - **Estimated Time:** 2 weeks
#    - **Resources Required:** 1 Software Engineer
#    - **Effort:** 40 hours
#    - **Deliverables:** Functional blog on the site.
#    - **Risks/Uncertainties:** Ensuring compatibility with SEO might increase effort.
#
# 10. **SEO and Performance Optimization**
#     - **Estimated Time:** 2 weeks
#     - **Resources Required:** 2 Quality Assurance Engineers
#     - **Effort:** 80 hours (40 hours per engineer)
#     - **Deliverables:** SEO report, optimized site.
#     - **Risks/Uncertainties:** SEO practices may require additional iterations.
#
# 11. **Social Media Integration**
#     - **Estimated Time:** 2 weeks
#     - **Resources Required:** 1 Software Engineer
#     - **Effort:** 20 hours
#     - **Deliverables:** Social media buttons working.
#     - **Risks/Uncertainties:** May depend on the completion of prior marketing materials.
#
# 12. **Testimonials Section Design**
#     - **Estimated Time:** 2 weeks
#     - **Resources Required:** 1 Content Creator
#     - **Effort:** 40 hours
#     - **Deliverables:** Live testimonials section.
#     - **Risks/Uncertainties:** Client feedback cycles will influence completion.
#
# 13. **Quality Assurance Testing**
#     - **Estimated Time:** 2 weeks
#     - **Resources Required:** 2 Quality Assurance Engineers
#     - **Effort:** 80 hours (40 hours per engineer)
#     - **Deliverables:** QA testing report with any bugs identified.
#     - **Risks/Uncertainties:** Unidentified bugs may require additional testing cycles.
#
# 14. **Final Review and Client Approval**
#     - **Estimated Time:** 1 week
#     - **Resources Required:** 1 Project Manager
#     - **Effort:** 20 hours
#     - **Deliverables:** Client approval confirmation.
#     - **Risks/Uncertainties:** Feedback may necessitate rework.
#
# 15. **Deployment and Launch**
#     - **Estimated Time:** 1 week
#     - **Resources Required:** 1 Software Engineer, 1 Project Manager
#     - **Effort:** 40 hours (20 hours each)
#     - **Deliverables:** Live website.
#     - **Risks/Uncertainties:** Deployment issues could arise if previous steps haven't been completed correctly.
#
# ### Summary of Risks and Uncertainties
# - **Communication Delays:** Stakeholder availability and delays in feedback can impact timelines.
# - **Resource Availability:** Team members may be unavailable due to concurrent projects.
# - **Technical Challenges:** Implementing responsive design and integrations might need additional time if unexpected issues arise.
# - **Content Dependencies:** Approval processes for content may introduce bottlenecks.
#
# In conclusion, careful monitoring of task progress and proactive management of dependencies, risks, and stakeholder communication will be essential to keep the project on track and within budget. The outlined estimations are grounded in historical data and best practices, reflecting a comprehensive approach to ensure timely project delivery.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - PM Pro (Project Manager)
# - Architect Aaron (Architect)
# - Software Eng Doe (Software Engineer)
# - Designer Smith (Designer)
# - QA Johnson (QA Engineer)
# - QA Brown (QA Engineer)
# - Creator Moe (Content Creator)
#
#
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# {
#   "tasks": [
#     {
#       "task_name": "Requirement Gathering",
#       "estimated_time_hours": 80,
#       "required_resources": ["PM Pro"]
#     },
#     {
#       "task_name": "Create Wireframes & Design",
#       "estimated_time_hours": 60,
#       "required_resources": ["Designer Smith"]
#     },
#     {
#       "task_name": "Responsive Design Implementation",
#       "estimated_time_hours": 80,
#       "required_resources": ["Architect Aaron"]
#     },
#     {
#       "task_name": "User Interface Development",
#       "estimated_time_hours": 80,
#       "required_resources": ["Software Eng Doe"]
#     },
#     {
#       "task_name": "Navigation Structure Development",
#       "estimated_time_hours": 40,
#       "required_resources": ["Software Eng Doe"]
#     },
#     {
#       "task_name": "Content Creation for 'About Us' Page",
#       "estimated_time_hours": 30,
#       "required_resources": ["Creator Moe"]
#     },
#     {
#       "task_name": "'Services' Page Design and Development",
#       "estimated_time_hours": 60,
#       "required_resources": ["Software Eng Doe", "Creator Moe"]
#     },
#     {
#       "task_name": "'Contact Us' Page Design",
#       "estimated_time_hours": 40,
#       "required_resources": ["Software Eng Doe"]
#     },
#     {
#       "task_name": "Blog Section Implementation",
#       "estimated_time_hours": 40,
#       "required_resources": ["Software Eng Doe"]
#     },
#     {
#       "task_name": "SEO and Performance Optimization",
#       "estimated_time_hours": 80,
#       "required_resources": ["QA Johnson", "QA Brown"]
#     },
#     {
#       "task_name": "Social Media Integration",
#       "estimated_time_hours": 20,
#       "required_resources": ["Software Eng Doe"]
#     },
#     {
#       "task_name": "Testimonials Section Design",
#       "estimated_time_hours": 40,
#       "required_resources": ["Creator Moe"]
#     },
#     {
#       "task_name": "Quality Assurance Testing",
#       "estimated_time_hours": 80,
#       "required_resources": ["QA Johnson", "QA Brown"]
#     },
#     {
#       "task_name": "Final Review and Client Approval",
#       "estimated_time_hours": 20,
#       "required_resources": ["PM Pro"]
#     },
#     {
#       "task_name": "Deployment and Launch",
#       "estimated_time_hours": 40,
#       "required_resources": ["Software Eng Doe", "PM Pro"]
#     }
#   ],
#   "milestones": [
#     {
#       "milestone_name": "Project Kickoff",
#       "tasks": ["Requirement Gathering"]
#     },
#     {
#       "milestone_name": "Design Phase Completion",
#       "tasks": ["Create Wireframes & Design", "Responsive Design Implementation", "User Interface Development"]
#     },
#     {
#       "milestone_name": "Development Phase Completion",
#       "tasks": ["'Services' Page Design and Development", "'Contact Us' Page Design", "Blog Section Implementation"]
#     },
#     {
#       "milestone_name": "Testing Phase Completion",
#       "tasks": ["Quality Assurance Testing"]
#     },
#     {
#       "milestone_name": "Final Review and Launch",
#       "tasks": ["Final Review and Client Approval", "Deployment and Launch"]
#     }
#   ]
# }
#
# Rationale:
#
# 1. **PM Pro** is allocated to manage the entire project, overseeing critical tasks like requirement gathering and final review to ensure smooth communication and stakeholder engagement.
# 2. **Designer Smith** focuses on creating wireframes and design, which is essential for the visual aspect of the website—this task is crucial early on and done solely by the designer for clarity and consistency.
# 3. **Architect Aaron** is assigned to implement responsive design as this task requires specific architectural skills to ensure compatibility across various devices.
# 4. **Software Eng Doe** is tasked with both user interface development and a series of other related tasks (navigation, services, contact, blog, and social media integration) due to their skill set in front-end development and to maintain consistency in the coding style and integration.
# 5. **Creator Moe** focuses on content creation for 'About Us', 'Services', and testimonials. His role is vital for producing the website's textual content, which is foundational for design and implementation.
# 6. **QA Engineers (Johnson and Brown)** are essential for both SEO optimization and testing, ensuring that the website functions as expected and meets quality standards before launch.
# 7. Milestones are created to ensure project promotes clarity in timelines and deliverables, facilitating better tracking of progress and resource allocation.
#
# This allocation optimally utilizes each team member's expertise while evenly distributing workload to prevent burnout and enhance project efficiency.

# %% [markdown]
# ## Result

# %%
pprint.pprint(result.pydantic.dict())
# Out:
# {'milestones': [{'milestone_name': 'Project Kickoff',
#                  'tasks': ['Requirement Gathering']},
#                 {'milestone_name': 'Design Phase Completion',
#                  'tasks': ['Create Wireframes & Design',
#                            'Responsive Design Implementation',
#                            'User Interface Development']},
#                 {'milestone_name': 'Development Phase Completion',
#                  'tasks': ["'Services' Page Design and Development",
#                            "'Contact Us' Page Design",
#                            'Blog Section Implementation']},
#                 {'milestone_name': 'Testing Phase Completion',
#                  'tasks': ['Quality Assurance Testing']},
#                 {'milestone_name': 'Final Review and Launch',
#                  'tasks': ['Final Review and Client Approval',
#                            'Deployment and Launch']}],
#  'tasks': [{'estimated_time_hours': 80.0,
#             'required_resources': ['PM Pro'],
#             'task_name': 'Requirement Gathering'},
#            {'estimated_time_hours': 60.0,
#             'required_resources': ['Designer Smith'],
#             'task_name': 'Create Wireframes & Design'},
#            {'estimated_time_hours': 80.0,
#             'required_resources': ['Architect Aaron'],
#             'task_name': 'Responsive Design Implementation'},
#            {'estimated_time_hours': 80.0,
#             'required_resources': ['Software Eng Doe'],
#             'task_name': 'User Interface Development'},
#            {'estimated_time_hours': 40.0,
#             'required_resources': ['Software Eng Doe'],
#             'task_name': 'Navigation Structure Development'},
#            {'estimated_time_hours': 30.0,
#             'required_resources': ['Creator Moe'],
#             'task_name': "Content Creation for 'About Us' Page"},
#            {'estimated_time_hours': 60.0,
#             'required_resources': ['Software Eng Doe', 'Creator Moe'],
#             'task_name': "'Services' Page Design and Development"},
#            {'estimated_time_hours': 40.0,
#             'required_resources': ['Software Eng Doe'],
#             'task_name': "'Contact Us' Page Design"},
#            {'estimated_time_hours': 40.0,
#             'required_resources': ['Software Eng Doe'],
#             'task_name': 'Blog Section Implementation'},
#            {'estimated_time_hours': 80.0,
#             'required_resources': ['QA Johnson', 'QA Brown'],
#             'task_name': 'SEO and Performance Optimization'},
#            {'estimated_time_hours': 20.0,
#             'required_resources': ['Software Eng Doe'],
#             'task_name': 'Social Media Integration'},
#            {'estimated_time_hours': 40.0,
#             'required_resources': ['Creator Moe'],
#             'task_name': 'Testimonials Section Design'},
#            {'estimated_time_hours': 80.0,
#             'required_resources': ['QA Johnson', 'QA Brown'],
#             'task_name': 'Quality Assurance Testing'},
#            {'estimated_time_hours': 20.0,
#             'required_resources': ['PM Pro'],
#             'task_name': 'Final Review and Client Approval'},
#            {'estimated_time_hours': 40.0,
#             'required_resources': ['Software Eng Doe', 'PM Pro'],
#             'task_name': 'Deployment and Launch'}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_fea59 th {
#   font-size: 120%;
# }
# #T_fea59  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_fea59" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fea59_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_fea59_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_fea59_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fea59_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fea59_row0_col0" class="data row0 col0" >Requirement Gathering</td>
#       <td id="T_fea59_row0_col1" class="data row0 col1" >80.000000</td>
#       <td id="T_fea59_row0_col2" class="data row0 col2" >['PM Pro']</td>
#     </tr>
#     <tr>
#       <th id="T_fea59_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fea59_row1_col0" class="data row1 col0" >Create Wireframes & Design</td>
#       <td id="T_fea59_row1_col1" class="data row1 col1" >60.000000</td>
#       <td id="T_fea59_row1_col2" class="data row1 col2" >['Designer Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_fea59_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fea59_row2_col0" class="data row2 col0" >Responsive Design Implementation</td>
#       <td id="T_fea59_row2_col1" class="data row2 col1" >80.000000</td>
#       <td id="T_fea59_row2_col2" class="data row2 col2" >['Architect Aaron']</td>
#     </tr>
#     <tr>
#       <th id="T_fea59_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fea59_row3_col0" class="data row3 col0" >User Interface Development</td>
#       <td id="T_fea59_row3_col1" class="data row3 col1" >80.000000</td>
#       <td id="T_fea59_row3_col2" class="data row3 col2" >['Software Eng Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_fea59_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fea59_row4_col0" class="data row4 col0" >Navigation Structure Development</td>
#       <td id="T_fea59_row4_col1" class="data row4 col1" >40.000000</td>
#       <td id="T_fea59_row4_col2" class="data row4 col2" >['Software Eng Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_fea59_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fea59_row5_col0" class="data row5 col0" >Content Creation for 'About Us' Page</td>
#       <td id="T_fea59_row5_col1" class="data row5 col1" >30.000000</td>
#       <td id="T_fea59_row5_col2" class="data row5 col2" >['Creator Moe']</td>
#     </tr>
#     <tr>
#       <th id="T_fea59_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fea59_row6_col0" class="data row6 col0" >'Services' Page Design and Development</td>
#       <td id="T_fea59_row6_col1" class="data row6 col1" >60.000000</td>
#       <td id="T_fea59_row6_col2" class="data row6 col2" >['Software Eng Doe', 'Creator Moe']</td>
#     </tr>
#     <tr>
#       <th id="T_fea59_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fea59_row7_col0" class="data row7 col0" >'Contact Us' Page Design</td>
#       <td id="T_fea59_row7_col1" class="data row7 col1" >40.000000</td>
#       <td id="T_fea59_row7_col2" class="data row7 col2" >['Software Eng Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_fea59_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fea59_row8_col0" class="data row8 col0" >Blog Section Implementation</td>
#       <td id="T_fea59_row8_col1" class="data row8 col1" >40.000000</td>
#       <td id="T_fea59_row8_col2" class="data row8 col2" >['Software Eng Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_fea59_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fea59_row9_col0" class="data row9 col0" >SEO and Performance Optimization</td>
#       <td id="T_fea59_row9_col1" class="data row9 col1" >80.000000</td>
#       <td id="T_fea59_row9_col2" class="data row9 col2" >['QA Johnson', 'QA Brown']</td>
#     </tr>
#     <tr>
#       <th id="T_fea59_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fea59_row10_col0" class="data row10 col0" >Social Media Integration</td>
#       <td id="T_fea59_row10_col1" class="data row10 col1" >20.000000</td>
#       <td id="T_fea59_row10_col2" class="data row10 col2" >['Software Eng Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_fea59_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fea59_row11_col0" class="data row11 col0" >Testimonials Section Design</td>
#       <td id="T_fea59_row11_col1" class="data row11 col1" >40.000000</td>
#       <td id="T_fea59_row11_col2" class="data row11 col2" >['Creator Moe']</td>
#     </tr>
#     <tr>
#       <th id="T_fea59_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_fea59_row12_col0" class="data row12 col0" >Quality Assurance Testing</td>
#       <td id="T_fea59_row12_col1" class="data row12 col1" >80.000000</td>
#       <td id="T_fea59_row12_col2" class="data row12 col2" >['QA Johnson', 'QA Brown']</td>
#     </tr>
#     <tr>
#       <th id="T_fea59_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_fea59_row13_col0" class="data row13 col0" >Final Review and Client Approval</td>
#       <td id="T_fea59_row13_col1" class="data row13 col1" >20.000000</td>
#       <td id="T_fea59_row13_col2" class="data row13 col2" >['PM Pro']</td>
#     </tr>
#     <tr>
#       <th id="T_fea59_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_fea59_row14_col0" class="data row14 col0" >Deployment and Launch</td>
#       <td id="T_fea59_row14_col1" class="data row14 col1" >40.000000</td>
#       <td id="T_fea59_row14_col2" class="data row14 col2" >['Software Eng Doe', 'PM Pro']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Inspect Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_058c3 th {
#   font-size: 120%;
# }
# #T_058c3  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_058c3" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_058c3_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_058c3_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_058c3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_058c3_row0_col0" class="data row0 col0" >Project Kickoff</td>
#       <td id="T_058c3_row0_col1" class="data row0 col1" >['Requirement Gathering']</td>
#     </tr>
#     <tr>
#       <th id="T_058c3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_058c3_row1_col0" class="data row1 col0" >Design Phase Completion</td>
#       <td id="T_058c3_row1_col1" class="data row1 col1" >['Create Wireframes & Design', 'Responsive Design Implementation', 'User Interface Development']</td>
#     </tr>
#     <tr>
#       <th id="T_058c3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_058c3_row2_col0" class="data row2 col0" >Development Phase Completion</td>
#       <td id="T_058c3_row2_col1" class="data row2 col1" >["'Services' Page Design and Development", "'Contact Us' Page Design", 'Blog Section Implementation']</td>
#     </tr>
#     <tr>
#       <th id="T_058c3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_058c3_row3_col0" class="data row3 col0" >Testing Phase Completion</td>
#       <td id="T_058c3_row3_col1" class="data row3 col1" >['Quality Assurance Testing']</td>
#     </tr>
#     <tr>
#       <th id="T_058c3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_058c3_row4_col0" class="data row4 col0" >Final Review and Launch</td>
#       <td id="T_058c3_row4_col1" class="data row4 col1" >['Final Review and Client Approval', 'Deployment and Launch']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Usage Metrics and Costs

# %%
import pandas as pd

costs = ( (0.150 * crew.usage_metrics.prompt_tokens) + (0.600 * crew.usage_metrics.completion_tokens) ) / 1_000_000
print(f"Total costs: ${costs:.5f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.00328
#    total_tokens  prompt_tokens  cached_prompt_tokens  completion_tokens  \
# 0          8912           4584                     0               4328
#
#    successful_requests
# 0                    3
